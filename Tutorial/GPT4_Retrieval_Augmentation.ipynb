# %% [markdown]
# # Retrieval Augmentation for GPT-4 using Pinecone
#
# #### Fixing LLMs that Hallucinate
#
# In this notebook we will learn how to query relevant contexts to our queries from Pinecone, and pass these to a GPT-4 model to generate an answer backed by real data sources.
#
# GPT-4 is a big step up from previous OpenAI completion models. It also exclusively uses the `ChatCompletion` endpoint, so we must use it in a slightly different way to usual. However, the power of the model makes the change worthwhile, particularly when augmented with an external knowledge base like the Pinecone vector database.
#
# Original Notebook link:
# https://github.com/openai/openai-cookbook/tree/main/examples/vector_databases/pinecone
#
#
# Modified by John Tan Chong Min on 11 Apr
#
# Required installs for this notebook are:

# %%
# !pip install -qU bs4 tiktoken openai langchain pinecone-client[grpc]
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.4/515.4 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 24.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.0/223.0 kB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.0/218.0 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.0/218.0 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.7/211.7 kB 17.9 MB/s eta 0:00:00
#   Building wheel for bs4 (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.3 which is incompatible.
# tensorflow-hub 0.13.0 requires protobuf>=3.19.6, but you have protobuf 3.19.3 which is incompatible.
# tensorboard 2.12.1 requires protobuf>=3.19.6, but you have protobuf 3.19.3 which is incompatible.
# google-cloud-translate 3.8.4 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.19.3 which is incompatible.
# google-cloud-language 2.6.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.19.3 which is incompatible.
# google-cloud-firestore 2.7.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.19.3 which is incompatible.
# google-cloud-datastore 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.19.3 which is incompatible.
# google-cloud-bigquery 3.4.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.19.3 which is incompatible.
# google-cloud-bigquery-storage 2.19.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.19.3 which is incompatible.
# google-api-core 2.11.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.19.3 which is incompatible.

# %% [markdown]
# ## Preparing the Data

# %% [markdown]
# In this example, we will download the Langchain Documentation from [https://python.langchain.com/en/latest/](https://python.langchain.com/en/latest/). We get all `.html` files located on the site like so:

# %%
# !wget -r -A.html -P rtdocs https://python.langchain.com/en/latest/
# Out:
# --2023-04-11 03:27:27--  https://python.langchain.com/en/latest/
# Resolving python.langchain.com (python.langchain.com)... 104.17.33.82, 104.17.32.82, 2606:4700::6811:2152, ...
# Connecting to python.langchain.com (python.langchain.com)|104.17.33.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/index.html’
#
# python.langchain.co     [ <=>                ]  77.68K  --.-KB/s    in 0.01s
#
# 2023-04-11 03:27:27 (5.76 MB/s) - ‘rtdocs/python.langchain.com/en/latest/index.html’ saved [79548]
#
# Loading robots.txt; please ignore errors.
# --2023-04-11 03:27:27--  https://python.langchain.com/robots.txt
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 95 [text/plain]
# Saving to: ‘rtdocs/python.langchain.com/robots.txt.tmp’
#
# python.langchain.co 100%[===================>]      95  --.-KB/s    in 0s
#
# 2023-04-11 03:27:27 (17.2 MB/s) - ‘rtdocs/python.langchain.com/robots.txt.tmp’ saved [95/95]
#
# --2023-04-11 03:27:27--  https://python.langchain.com/en/latest/index.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/index.html’
#
# python.langchain.co     [ <=>                ]  77.68K  --.-KB/s    in 0.005s
#
# 2023-04-11 03:27:27 (13.9 MB/s) - ‘rtdocs/python.langchain.com/en/latest/index.html’ saved [79548]
#
# --2023-04-11 03:27:27--  https://python.langchain.com/en/latest/genindex.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/genindex.html’
#
# python.langchain.co     [ <=>                ] 249.88K  --.-KB/s    in 0.02s
#
# 2023-04-11 03:27:28 (11.7 MB/s) - ‘rtdocs/python.langchain.com/en/latest/genindex.html’ saved [255873]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/search.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/search.html’
#
# python.langchain.co     [ <=>                ]  66.12K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:28 (70.7 MB/s) - ‘rtdocs/python.langchain.com/en/latest/search.html’ saved [67711]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/getting_started/getting_started.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/getting_started/getting_started.html’
#
# python.langchain.co     [ <=>                ] 122.72K  --.-KB/s    in 0.003s
#
# 2023-04-11 03:27:28 (38.9 MB/s) - ‘rtdocs/python.langchain.com/en/latest/getting_started/getting_started.html’ saved [125663]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models.html’
#
# python.langchain.co     [ <=>                ]  68.19K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:28 (68.4 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models.html’ saved [69822]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms.html’
#
# python.langchain.co     [ <=>                ]  67.46K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:28 (72.0 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms.html’ saved [69074]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms/getting_started.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/getting_started.html’
#
# python.langchain.co     [ <=>                ]  74.57K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:28 (74.2 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/getting_started.html’ saved [76361]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms/how_to_guides.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/how_to_guides.html’
#
# python.langchain.co     [ <=>                ]  68.33K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:28 (68.1 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/how_to_guides.html’ saved [69968]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms/examples/async_llm.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/async_llm.html’
#
# python.langchain.co     [ <=>                ]  75.92K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:28 (38.1 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/async_llm.html’ saved [77744]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms/examples/custom_llm.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/custom_llm.html’
#
# python.langchain.co     [ <=>                ]  74.12K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:28 (52.9 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/custom_llm.html’ saved [75898]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms/examples/fake_llm.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/fake_llm.html’
#
# python.langchain.co     [ <=>                ]  72.62K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:28 (71.1 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/fake_llm.html’ saved [74366]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms/examples/llm_caching.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/llm_caching.html’
#
# python.langchain.co     [ <=>                ]  94.38K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:28 (45.5 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/llm_caching.html’ saved [96643]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms/examples/llm_serialization.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/llm_serialization.html’
#
# python.langchain.co     [ <=>                ]  73.88K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:28 (62.4 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/llm_serialization.html’ saved [75654]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms/examples/streaming_llm.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/streaming_llm.html’
#
# python.langchain.co     [ <=>                ]  78.60K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:28 (42.9 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/streaming_llm.html’ saved [80490]
#
# --2023-04-11 03:27:28--  https://python.langchain.com/en/latest/modules/models/llms/examples/token_usage_tracking.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/token_usage_tracking.html’
#
# python.langchain.co     [ <=>                ]  79.30K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:29 (37.8 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/examples/token_usage_tracking.html’ saved [81206]
#
# --2023-04-11 03:27:29--  https://python.langchain.com/en/latest/modules/models/llms/integrations.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations.html’
#
# python.langchain.co     [ <=>                ]  69.97K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:29 (70.0 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations.html’ saved [71648]
#
# --2023-04-11 03:27:29--  https://python.langchain.com/en/latest/modules/models/llms/integrations/ai21.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/ai21.html’
#
# python.langchain.co     [ <=>                ]  70.72K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:29 (67.2 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/ai21.html’ saved [72418]
#
# --2023-04-11 03:27:29--  https://python.langchain.com/en/latest/modules/models/llms/integrations/aleph_alpha.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/aleph_alpha.html’
#
# python.langchain.co     [ <=>                ]  71.35K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:29 (64.6 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/aleph_alpha.html’ saved [73063]
#
# --2023-04-11 03:27:29--  https://python.langchain.com/en/latest/modules/models/llms/integrations/anthropic_example.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/anthropic_example.html’
#
# python.langchain.co     [ <=>                ]  71.41K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:29 (50.8 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/anthropic_example.html’ saved [73124]
#
# --2023-04-11 03:27:29--  https://python.langchain.com/en/latest/modules/models/llms/integrations/azure_openai_example.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/azure_openai_example.html’
#
# python.langchain.co     [ <=>                ]  75.97K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:29 (42.7 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/azure_openai_example.html’ saved [77789]
#
# --2023-04-11 03:27:29--  https://python.langchain.com/en/latest/modules/models/llms/integrations/banana.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/banana.html’
#
# python.langchain.co     [ <=>                ]  71.23K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:29 (66.3 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/banana.html’ saved [72943]
#
# --2023-04-11 03:27:29--  https://python.langchain.com/en/latest/modules/models/llms/integrations/cerebriumai_example.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/cerebriumai_example.html’
#
# python.langchain.co     [ <=>                ]  76.32K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:30 (45.8 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/cerebriumai_example.html’ saved [78154]
#
# --2023-04-11 03:27:30--  https://python.langchain.com/en/latest/modules/models/llms/integrations/cohere.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/cohere.html’
#
# python.langchain.co     [ <=>                ]  72.04K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:30 (61.5 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/cohere.html’ saved [73772]
#
# --2023-04-11 03:27:30--  https://python.langchain.com/en/latest/modules/models/llms/integrations/deepinfra_example.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/deepinfra_example.html’
#
# python.langchain.co     [ <=>                ]  75.59K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:30 (48.4 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/deepinfra_example.html’ saved [77402]
#
# --2023-04-11 03:27:30--  https://python.langchain.com/en/latest/modules/models/llms/integrations/forefrontai_example.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/forefrontai_example.html’
#
# python.langchain.co     [ <=>                ]  75.37K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:30 (43.8 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/forefrontai_example.html’ saved [77177]
#
# --2023-04-11 03:27:30--  https://python.langchain.com/en/latest/modules/models/llms/integrations/gooseai_example.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/gooseai_example.html’
#
# python.langchain.co     [ <=>                ]  76.06K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:30 (54.1 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/gooseai_example.html’ saved [77888]
#
# --2023-04-11 03:27:30--  https://python.langchain.com/en/latest/modules/models/llms/integrations/gpt4all.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/gpt4all.html’
#
# python.langchain.co     [ <=>                ]  75.35K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:30 (48.0 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/gpt4all.html’ saved [77158]
#
# --2023-04-11 03:27:30--  https://python.langchain.com/en/latest/modules/models/llms/integrations/huggingface_hub.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/huggingface_hub.html’
#
# python.langchain.co     [ <=>                ]  70.61K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:30 (76.6 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/huggingface_hub.html’ saved [72304]
#
# --2023-04-11 03:27:30--  https://python.langchain.com/en/latest/modules/models/llms/integrations/llamacpp.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/llamacpp.html’
#
# python.langchain.co     [ <=>                ]  71.71K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:31 (63.8 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/llamacpp.html’ saved [73427]
#
# --2023-04-11 03:27:31--  https://python.langchain.com/en/latest/modules/models/llms/integrations/manifest.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/manifest.html’
#
# python.langchain.co     [ <=>                ]  79.89K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:31 (44.6 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/manifest.html’ saved [81807]
#
# --2023-04-11 03:27:31--  https://python.langchain.com/en/latest/modules/models/llms/integrations/modal.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/modal.html’
#
# python.langchain.co     [ <=>                ]  70.81K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:31 (62.1 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/modal.html’ saved [72512]
#
# --2023-04-11 03:27:31--  https://python.langchain.com/en/latest/modules/models/llms/integrations/openai.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/openai.html’
#
# python.langchain.co     [ <=>                ]  71.02K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:31 (76.2 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/openai.html’ saved [72722]
#
# --2023-04-11 03:27:31--  https://python.langchain.com/en/latest/modules/models/llms/integrations/petals_example.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/petals_example.html’
#
# python.langchain.co     [ <=>                ]  76.24K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:31 (44.1 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/petals_example.html’ saved [78070]
#
# --2023-04-11 03:27:31--  https://python.langchain.com/en/latest/modules/models/llms/integrations/promptlayer_openai.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/promptlayer_openai.html’
#
# python.langchain.co     [ <=>                ]  76.73K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:31 (45.7 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/promptlayer_openai.html’ saved [78576]
#
# --2023-04-11 03:27:31--  https://python.langchain.com/en/latest/modules/models/llms/integrations/replicate.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/replicate.html’
#
# python.langchain.co     [ <=>                ]  84.39K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:32 (45.1 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/replicate.html’ saved [86414]
#
# --2023-04-11 03:27:32--  https://python.langchain.com/en/latest/modules/models/llms/integrations/sagemaker.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/sagemaker.html’
#
# python.langchain.co     [ <=>                ]  75.77K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:32 (44.0 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/sagemaker.html’ saved [77591]
#
# --2023-04-11 03:27:32--  https://python.langchain.com/en/latest/modules/models/llms/integrations/self_hosted_examples.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/self_hosted_examples.html’
#
# python.langchain.co     [ <=>                ]  81.73K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:27:32 (43.0 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/self_hosted_examples.html’ saved [83693]
#
# --2023-04-11 03:27:32--  https://python.langchain.com/en/latest/modules/models/llms/integrations/stochasticai.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/stochasticai.html’
#
# python.langchain.co     [ <=>                ]  70.95K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:32 (48.7 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/stochasticai.html’ saved [72649]
#
# --2023-04-11 03:27:32--  https://python.langchain.com/en/latest/modules/models/llms/integrations/writer.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/writer.html’
#
# python.langchain.co     [ <=>                ]  70.76K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:32 (58.5 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/llms/integrations/writer.html’ saved [72456]
#
# --2023-04-11 03:27:32--  https://python.langchain.com/en/latest/reference/modules/llms.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/reference/modules/llms.html’
#
# python.langchain.co     [ <=>                ]   1.02M  --.-KB/s    in 0.03s
#
# 2023-04-11 03:27:32 (36.5 MB/s) - ‘rtdocs/python.langchain.com/en/latest/reference/modules/llms.html’ saved [1066070]
#
# --2023-04-11 03:27:32--  https://python.langchain.com/en/latest/modules/models/chat.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/chat.html’
#
# python.langchain.co     [ <=>                ]  67.54K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:33 (335 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/chat.html’ saved [69163]
#
# --2023-04-11 03:27:33--  https://python.langchain.com/en/latest/modules/models/chat/getting_started.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/getting_started.html’
#
# python.langchain.co     [ <=>                ]  86.62K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:33 (353 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/getting_started.html’ saved [88703]
#
# --2023-04-11 03:27:33--  https://python.langchain.com/en/latest/modules/models/chat/how_to_guides.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/how_to_guides.html’
#
# python.langchain.co     [ <=>                ]  67.86K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:33 (250 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/how_to_guides.html’ saved [69490]
#
# --2023-04-11 03:27:33--  https://python.langchain.com/en/latest/modules/models/chat/examples/few_shot_examples.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/examples/few_shot_examples.html’
#
# python.langchain.co     [ <=>                ]  79.06K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:33 (258 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/examples/few_shot_examples.html’ saved [80956]
#
# --2023-04-11 03:27:33--  https://python.langchain.com/en/latest/modules/models/chat/examples/streaming.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/examples/streaming.html’
#
# python.langchain.co     [ <=>                ]  71.89K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:33 (317 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/examples/streaming.html’ saved [73616]
#
# --2023-04-11 03:27:33--  https://python.langchain.com/en/latest/modules/models/chat/integrations.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/integrations.html’
#
# python.langchain.co     [ <=>                ]  67.92K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:34 (251 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/integrations.html’ saved [69553]
#
# --2023-04-11 03:27:34--  https://python.langchain.com/en/latest/modules/models/chat/integrations/azure_chat_openai.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/integrations/azure_chat_openai.html’
#
# python.langchain.co     [ <=>                ]  71.18K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:34 (194 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/integrations/azure_chat_openai.html’ saved [72890]
#
# --2023-04-11 03:27:34--  https://python.langchain.com/en/latest/modules/models/chat/integrations/openai.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/integrations/openai.html’
#
# python.langchain.co     [ <=>                ]  74.89K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:34 (340 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/integrations/openai.html’ saved [76684]
#
# --2023-04-11 03:27:34--  https://python.langchain.com/en/latest/modules/models/chat/integrations/promptlayer_chatopenai.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/integrations/promptlayer_chatopenai.html’
#
# python.langchain.co     [ <=>                ]  77.69K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:34 (360 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/chat/integrations/promptlayer_chatopenai.html’ saved [79556]
#
# --2023-04-11 03:27:34--  https://python.langchain.com/en/latest/modules/models/text_embedding.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding.html’
#
# python.langchain.co     [ <=>                ]  69.21K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:34 (215 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding.html’ saved [70867]
#
# --2023-04-11 03:27:34--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/aleph_alpha.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/aleph_alpha.html’
#
# python.langchain.co     [ <=>                ]  73.98K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:34 (235 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/aleph_alpha.html’ saved [75757]
#
# --2023-04-11 03:27:34--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/azureopenai.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/azureopenai.html’
#
# python.langchain.co     [ <=>                ]  71.29K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:34 (303 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/azureopenai.html’ saved [73004]
#
# --2023-04-11 03:27:34--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/cohere.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/cohere.html’
#
# python.langchain.co     [ <=>                ]  70.24K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:35 (81.7 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/cohere.html’ saved [71929]
#
# --2023-04-11 03:27:35--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/fake.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/fake.html’
#
# python.langchain.co     [ <=>                ]  70.02K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:35 (223 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/fake.html’ saved [71705]
#
# --2023-04-11 03:27:35--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/huggingfacehub.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/huggingfacehub.html’
#
# python.langchain.co     [ <=>                ]  70.24K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:35 (197 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/huggingfacehub.html’ saved [71928]
#
# --2023-04-11 03:27:35--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/instruct_embeddings.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/instruct_embeddings.html’
#
# python.langchain.co     [ <=>                ]  70.21K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:35 (192 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/instruct_embeddings.html’ saved [71893]
#
# --2023-04-11 03:27:35--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/jina.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/jina.html’
#
# python.langchain.co     [ <=>                ]  70.76K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:35 (213 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/jina.html’ saved [72458]
#
# --2023-04-11 03:27:35--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/llamacpp.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/llamacpp.html’
#
# python.langchain.co     [ <=>                ]  70.56K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:36 (167 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/llamacpp.html’ saved [72258]
#
# --2023-04-11 03:27:36--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/openai.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/openai.html’
#
# python.langchain.co     [ <=>                ]  72.39K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:36 (290 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/openai.html’ saved [74124]
#
# --2023-04-11 03:27:36--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/sagemaker-endpoint.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/sagemaker-endpoint.html’
#
# python.langchain.co     [ <=>                ]  73.98K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:36 (212 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/sagemaker-endpoint.html’ saved [75756]
#
# --2023-04-11 03:27:36--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/self-hosted.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/self-hosted.html’
#
# python.langchain.co     [ <=>                ]  76.51K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:36 (240 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/self-hosted.html’ saved [78344]
#
# --2023-04-11 03:27:36--  https://python.langchain.com/en/latest/modules/models/text_embedding/examples/tensorflowhub.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/tensorflowhub.html’
#
# python.langchain.co     [ <=>                ]  71.31K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:36 (302 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/models/text_embedding/examples/tensorflowhub.html’ saved [73020]
#
# --2023-04-11 03:27:36--  https://python.langchain.com/en/latest/modules/prompts.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts.html’
#
# python.langchain.co     [ <=>                ]  68.71K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:36 (240 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts.html’ saved [70357]
#
# --2023-04-11 03:27:36--  https://python.langchain.com/en/latest/modules/prompts/prompt_templates.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates.html’
#
# python.langchain.co     [ <=>                ]  67.83K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:36 (295 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates.html’ saved [69460]
#
# --2023-04-11 03:27:36--  https://python.langchain.com/en/latest/modules/prompts/prompt_templates/getting_started.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/getting_started.html’
#
# python.langchain.co     [ <=>                ]  91.19K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:36 (308 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/getting_started.html’ saved [93378]
#
# --2023-04-11 03:27:36--  https://python.langchain.com/en/latest/modules/prompts/prompt_templates/how_to_guides.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/how_to_guides.html’
#
# python.langchain.co     [ <=>                ]  68.67K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:37 (204 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/how_to_guides.html’ saved [70320]
#
# --2023-04-11 03:27:37--  https://python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/custom_prompt_template.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/custom_prompt_template.html’
#
# python.langchain.co     [ <=>                ]  79.59K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:37 (281 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/custom_prompt_template.html’ saved [81497]
#
# --2023-04-11 03:27:37--  https://python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/few_shot_examples.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/few_shot_examples.html’
#
# python.langchain.co     [ <=>                ]  91.73K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:37 (202 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/few_shot_examples.html’ saved [93928]
#
# --2023-04-11 03:27:37--  https://python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/partial.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/partial.html’
#
# python.langchain.co     [ <=>                ]  80.09K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:37 (278 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/partial.html’ saved [82017]
#
# --2023-04-11 03:27:37--  https://python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/prompt_serialization.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/prompt_serialization.html’
#
# python.langchain.co     [ <=>                ]  93.14K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:37 (311 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/prompt_templates/examples/prompt_serialization.html’ saved [95379]
#
# --2023-04-11 03:27:37--  https://python.langchain.com/en/latest/reference/prompts.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/reference/prompts.html’
#
# python.langchain.co     [ <=>                ]  68.81K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:37 (337 MB/s) - ‘rtdocs/python.langchain.com/en/latest/reference/prompts.html’ saved [70461]
#
# --2023-04-11 03:27:37--  https://python.langchain.com/en/latest/reference/modules/prompt.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/reference/modules/prompt.html’
#
# python.langchain.co     [ <=>                ] 132.01K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:27:37 (242 MB/s) - ‘rtdocs/python.langchain.com/en/latest/reference/modules/prompt.html’ saved [135181]
#
# --2023-04-11 03:27:37--  https://python.langchain.com/en/latest/reference/modules/example_selector.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/reference/modules/example_selector.html’
#
# python.langchain.co     [ <=>                ]  97.29K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:37 (257 MB/s) - ‘rtdocs/python.langchain.com/en/latest/reference/modules/example_selector.html’ saved [99629]
#
# --2023-04-11 03:27:38--  https://python.langchain.com/en/latest/modules/prompts/chat_prompt_template.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/chat_prompt_template.html’
#
# python.langchain.co     [ <=>                ]  72.95K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:38 (286 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/chat_prompt_template.html’ saved [74704]
#
# --2023-04-11 03:27:38--  https://python.langchain.com/en/latest/modules/prompts/example_selectors.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors.html’
#
# python.langchain.co     [ <=>                ]  69.38K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:38 (277 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors.html’ saved [71040]
#
# --2023-04-11 03:27:38--  https://python.langchain.com/en/latest/modules/prompts/example_selectors/examples/custom_example_selector.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/custom_example_selector.html’
#
# python.langchain.co     [ <=>                ]  77.47K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:38 (330 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/custom_example_selector.html’ saved [79328]
#
# --2023-04-11 03:27:38--  https://python.langchain.com/en/latest/modules/prompts/example_selectors/examples/length_based.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/length_based.html’
#
# python.langchain.co     [ <=>                ]  78.46K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:38 (359 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/length_based.html’ saved [80344]
#
# --2023-04-11 03:27:38--  https://python.langchain.com/en/latest/modules/prompts/example_selectors/examples/mmr.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/mmr.html’
#
# python.langchain.co     [ <=>                ]  77.55K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:38 (218 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/mmr.html’ saved [79407]
#
# --2023-04-11 03:27:38--  https://python.langchain.com/en/latest/modules/prompts/example_selectors/examples/ngram_overlap.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/ngram_overlap.html’
#
# python.langchain.co     [ <=>                ]  83.06K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:38 (295 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/ngram_overlap.html’ saved [85052]
#
# --2023-04-11 03:27:38--  https://python.langchain.com/en/latest/modules/prompts/example_selectors/examples/similarity.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/similarity.html’
#
# python.langchain.co     [ <=>                ]  77.58K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:38 (242 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/example_selectors/examples/similarity.html’ saved [79442]
#
# --2023-04-11 03:27:38--  https://python.langchain.com/en/latest/modules/prompts/output_parsers.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/output_parsers.html’
#
# python.langchain.co     [ <=>                ]  69.38K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:39 (300 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/output_parsers.html’ saved [71047]
#
# --2023-04-11 03:27:39--  https://python.langchain.com/en/latest/modules/prompts/output_parsers/getting_started.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/output_parsers/getting_started.html’
#
# python.langchain.co     [ <=>                ]  76.69K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:39 (206 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/output_parsers/getting_started.html’ saved [78529]
#
# --2023-04-11 03:27:39--  https://python.langchain.com/en/latest/modules/prompts/output_parsers/examples/comma_separated.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/modules/prompts/output_parsers/examples/comma_separated.html’
#
# python.langchain.co     [ <=>                ]  73.19K  --.-KB/s    in 0s
#
# 2023-04-11 03:27:39 (184 MB/s) - ‘rtdocs/python.langchain.com/en/latest/modules/prompts/output_parsers/examples/comma_separated.html’ saved [74944]
#
# --2023-04-11 03:27:39--  https://python.langchain.com/en/latest/modules/prompts/output_parsers/examples/output_fixing_parser.html
# Reusing existing connection to python.langchain.com:443.
# ...
#
# 2023-04-11 03:28:31 (130 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/deeplake.html’ saved [141119]
#
# --2023-04-11 03:28:31--  https://python.langchain.com/en/latest/_modules/langchain/vectorstores/elastic_vector_search.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/elastic_vector_search.html’
#
# python.langchain.co     [ <=>                ] 100.56K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:31 (239 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/elastic_vector_search.html’ saved [102977]
#
# --2023-04-11 03:28:31--  https://python.langchain.com/en/latest/_modules/langchain/vectorstores/faiss.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/faiss.html’
#
# python.langchain.co     [ <=>                ] 126.98K  --.-KB/s    in 0.002s
#
# 2023-04-11 03:28:31 (56.1 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/faiss.html’ saved [130025]
#
# --2023-04-11 03:28:31--  https://python.langchain.com/en/latest/_modules/langchain/vectorstores/milvus.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/milvus.html’
#
# python.langchain.co     [ <=>                ] 127.25K  --.-KB/s    in 0.009s
#
# 2023-04-11 03:28:31 (13.8 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/milvus.html’ saved [130306]
#
# --2023-04-11 03:28:31--  https://python.langchain.com/en/latest/_modules/langchain/vectorstores/opensearch_vector_search.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/opensearch_vector_search.html’
#
# python.langchain.co     [ <=>                ] 120.39K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:31 (279 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/opensearch_vector_search.html’ saved [123275]
#
# --2023-04-11 03:28:31--  https://python.langchain.com/en/latest/_modules/langchain/vectorstores/pinecone.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/pinecone.html’
#
# python.langchain.co     [ <=>                ] 102.00K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:31 (292 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/pinecone.html’ saved [104450]
#
# --2023-04-11 03:28:31--  https://python.langchain.com/en/latest/_modules/langchain/vectorstores/qdrant.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/qdrant.html’
#
# python.langchain.co     [ <=>                ] 118.73K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:28:32 (172 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/qdrant.html’ saved [121581]
#
# --2023-04-11 03:28:32--  https://python.langchain.com/en/latest/_modules/langchain/vectorstores/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/base.html’
#
# python.langchain.co     [ <=>                ] 104.40K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:28:32 (191 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/base.html’ saved [106901]
#
# --2023-04-11 03:28:32--  https://python.langchain.com/en/latest/_modules/langchain/vectorstores/weaviate.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/weaviate.html’
#
# python.langchain.co     [ <=>                ]  87.08K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:32 (253 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/vectorstores/weaviate.html’ saved [89172]
#
# --2023-04-11 03:28:32--  https://python.langchain.com/en/latest/_modules/langchain/agents/agent.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent.html’
#
# python.langchain.co     [ <=>                ] 198.41K  --.-KB/s    in 0.003s
#
# 2023-04-11 03:28:32 (73.1 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent.html’ saved [203168]
#
# --2023-04-11 03:28:32--  https://python.langchain.com/en/latest/_modules/langchain/agents/agent_types.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_types.html’
#
# python.langchain.co     [ <=>                ]  70.28K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:32 (246 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_types.html’ saved [71968]
#
# --2023-04-11 03:28:32--  https://python.langchain.com/en/latest/_modules/langchain/agents/conversational/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/conversational/base.html’
#
# python.langchain.co     [ <=>                ]  88.66K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:33 (266 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/conversational/base.html’ saved [90784]
#
# --2023-04-11 03:28:33--  https://python.langchain.com/en/latest/_modules/langchain/agents/conversational_chat/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/conversational_chat/base.html’
#
# python.langchain.co     [ <=>                ]  93.10K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:33 (318 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/conversational_chat/base.html’ saved [95335]
#
# --2023-04-11 03:28:33--  https://python.langchain.com/en/latest/_modules/langchain/agents/mrkl/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/mrkl/base.html’
#
# python.langchain.co     [ <=>                ]  95.01K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:33 (306 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/mrkl/base.html’ saved [97289]
#
# --2023-04-11 03:28:33--  https://python.langchain.com/en/latest/_modules/langchain/agents/react/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/react/base.html’
#
# python.langchain.co     [ <=>                ]  95.59K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:33 (303 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/react/base.html’ saved [97885]
#
# --2023-04-11 03:28:33--  https://python.langchain.com/en/latest/_modules/langchain/agents/self_ask_with_search/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/self_ask_with_search/base.html’
#
# python.langchain.co     [ <=>                ]  82.85K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:33 (261 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/self_ask_with_search/base.html’ saved [84838]
#
# --2023-04-11 03:28:33--  https://python.langchain.com/en/latest/_modules/langchain/agents/tools.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/tools.html’
#
# python.langchain.co     [ <=>                ]  83.05K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:33 (200 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/tools.html’ saved [85039]
#
# --2023-04-11 03:28:33--  https://python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/csv/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/csv/base.html’
#
# python.langchain.co     [ <=>                ]  73.97K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:34 (277 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/csv/base.html’ saved [75749]
#
# --2023-04-11 03:28:34--  https://python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/json/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/json/base.html’
#
# python.langchain.co     [ <=>                ]  77.65K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:34 (337 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/json/base.html’ saved [79516]
#
# --2023-04-11 03:28:34--  https://python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/openapi/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/openapi/base.html’
#
# python.langchain.co     [ <=>                ]  78.16K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:34 (233 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/openapi/base.html’ saved [80032]
#
# --2023-04-11 03:28:34--  https://python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/pandas/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/pandas/base.html’
#
# python.langchain.co     [ <=>                ]  79.92K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:34 (239 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/pandas/base.html’ saved [81835]
#
# --2023-04-11 03:28:34--  https://python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/sql/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/sql/base.html’
#
# python.langchain.co     [ <=>                ]  78.91K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:34 (237 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/sql/base.html’ saved [80805]
#
# --2023-04-11 03:28:34--  https://python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/vectorstore/base.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/vectorstore/base.html’
#
# python.langchain.co     [ <=>                ]  80.24K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:34 (272 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/agent_toolkits/vectorstore/base.html’ saved [82162]
#
# --2023-04-11 03:28:34--  https://python.langchain.com/en/latest/_modules/langchain/agents/load_tools.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/load_tools.html’
#
# python.langchain.co     [ <=>                ] 113.34K  --.-KB/s    in 0.001s
#
# 2023-04-11 03:28:35 (196 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/load_tools.html’ saved [116063]
#
# --2023-04-11 03:28:35--  https://python.langchain.com/en/latest/_modules/langchain/agents/initialize.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/initialize.html’
#
# python.langchain.co     [ <=>                ]  77.49K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:35 (161 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/initialize.html’ saved [79347]
#
# --2023-04-11 03:28:35--  https://python.langchain.com/en/latest/_modules/langchain/agents/loading.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/loading.html’
#
# python.langchain.co     [ <=>                ]  86.01K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:35 (257 MB/s) - ‘rtdocs/python.langchain.com/en/latest/_modules/langchain/agents/loading.html’ saved [88076]
#
# --2023-04-11 03:28:35--  https://python.langchain.com/en/latest/tracing/local_installation.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/tracing/local_installation.html’
#
# python.langchain.co     [ <=>                ]  72.80K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:35 (233 MB/s) - ‘rtdocs/python.langchain.com/en/latest/tracing/local_installation.html’ saved [74547]
#
# --2023-04-11 03:28:35--  https://python.langchain.com/en/latest/tracing/hosted_installation.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/tracing/hosted_installation.html’
#
# python.langchain.co     [ <=>                ]  72.84K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:35 (168 MB/s) - ‘rtdocs/python.langchain.com/en/latest/tracing/hosted_installation.html’ saved [74585]
#
# --2023-04-11 03:28:35--  https://python.langchain.com/en/latest/tracing/agent_with_tracing.html
# Reusing existing connection to python.langchain.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/python.langchain.com/en/latest/tracing/agent_with_tracing.html’
#
# python.langchain.co     [ <=>                ]  77.11K  --.-KB/s    in 0s
#
# 2023-04-11 03:28:35 (193 MB/s) - ‘rtdocs/python.langchain.com/en/latest/tracing/agent_with_tracing.html’ saved [78957]
#
# FINISHED --2023-04-11 03:28:35--
# Total wall clock time: 1m 8s
# Downloaded: 475 files, 40M in 0.3s (128 MB/s)

# %% [markdown]
# This downloads all HTML into the `rtdocs` directory. Now we can use LangChain itself to process these docs. We do this using the `ReadTheDocsLoader` like so:

# %%
from langchain.document_loaders import ReadTheDocsLoader

loader = ReadTheDocsLoader('rtdocs')
docs = loader.load()
len(docs)
# Out:
# /usr/local/lib/python3.9/dist-packages/langchain/document_loaders/readthedocs.py:30: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 30 of the file /usr/local/lib/python3.9/dist-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   _ = BeautifulSoup(
# /usr/local/lib/python3.9/dist-packages/langchain/document_loaders/readthedocs.py:46: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 46 of the file /usr/local/lib/python3.9/dist-packages/langchain/document_loaders/readthedocs.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(data, **self.bs_kwargs)
# /usr/local/lib/python3.9/dist-packages/langchain/document_loaders/readthedocs.py:46: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(data, **self.bs_kwargs)
# 475

# %% [markdown]
# This leaves us with hundreds of processed doc pages. Let's take a look at the format each one contains:

# %%
docs[0]
# Out:
# Document(page_content='', metadata={'source': 'rtdocs/python.langchain.com/robots.txt.tmp'})

# %%
docs[1]
# Out:
# Document(page_content='.md\n.pdf\nTracing\n Contents \nTracing Walkthrough\nChanging Sessions\nTracing#\nBy enabling tracing in your LangChain runs, you’ll be able to more effectively visualize, step through, and debug your chains and agents.\nFirst, you should install tracing and set up your environment properly.\nYou can use either a locally hosted version of this (uses Docker) or a cloud hosted version (in closed alpha).\nIf you’re interested in using the hosted platform, please fill out the form here.\nLocally Hosted Setup\nCloud Hosted Setup\nTracing Walkthrough#\nWhen you first access the UI, you should see a page with your tracing sessions.\nAn initial one “default” should already be created for you.\nA session is just a way to group traces together.\nIf you click on a session, it will take you to a page with no recorded traces that says “No Runs.”\nYou can create a new session with the new session form.\nIf we click on the default session, we can see that to start we have no traces stored.\nIf we now start running chains and agents with tracing enabled, we will see data show up here.\nTo do so, we can run this notebook as an example.\nAfter running it, we will see an initial trace show up.\nFrom here we can explore the trace at a high level by clicking on the arrow to show nested runs.\nWe can keep on clicking further and further down to explore deeper and deeper.\nWe can also click on the “Explore” button of the top level run to dive even deeper.\nHere, we can see the inputs and outputs in full, as well as all the nested traces.\nWe can keep on exploring each of these nested traces in more detail.\nFor example, here is the lowest level trace with the exact inputs/outputs to the LLM.\nChanging Sessions#\nTo initially record traces to a session other than "default", you can set the LANGCHAIN_SESSION environment variable to the name of the session you want to record to:\nimport os\nos.environ["LANGCHAIN_HANDLER"] = "langchain"\nos.environ["LANGCHAIN_SESSION"] = "my_session" # Make sure this session actually exists. You can create a new session in the UI.\nTo switch sessions mid-script or mid-notebook, do NOT set the LANGCHAIN_SESSION environment variable. Instead: langchain.set_tracing_callback_manager(session_name="my_session")\nprevious\nDeployments\n Contents\n  \nTracing Walkthrough\nChanging Sessions\nBy Harrison Chase\n    \n      © Copyright 2023, Harrison Chase.\n      \n  Last updated on Apr 11, 2023.\n  ', metadata={'source': 'rtdocs/python.langchain.com/en/latest/tracing.html'})

# %% [markdown]
# We access the plaintext page content like so:

# %%
print(docs[1].page_content)
# Out:
# .md
# .pdf
# Tracing
#  Contents
# Tracing Walkthrough
# Changing Sessions
# Tracing#
# By enabling tracing in your LangChain runs, you’ll be able to more effectively visualize, step through, and debug your chains and agents.
# First, you should install tracing and set up your environment properly.
# You can use either a locally hosted version of this (uses Docker) or a cloud hosted version (in closed alpha).
# If you’re interested in using the hosted platform, please fill out the form here.
# Locally Hosted Setup
# Cloud Hosted Setup
# Tracing Walkthrough#
# When you first access the UI, you should see a page with your tracing sessions.
# An initial one “default” should already be created for you.
# A session is just a way to group traces together.
# If you click on a session, it will take you to a page with no recorded traces that says “No Runs.”
# You can create a new session with the new session form.
# If we click on the default session, we can see that to start we have no traces stored.
# If we now start running chains and agents with tracing enabled, we will see data show up here.
# To do so, we can run this notebook as an example.
# After running it, we will see an initial trace show up.
# From here we can explore the trace at a high level by clicking on the arrow to show nested runs.
# We can keep on clicking further and further down to explore deeper and deeper.
# We can also click on the “Explore” button of the top level run to dive even deeper.
# Here, we can see the inputs and outputs in full, as well as all the nested traces.
# We can keep on exploring each of these nested traces in more detail.
# For example, here is the lowest level trace with the exact inputs/outputs to the LLM.
# Changing Sessions#
# To initially record traces to a session other than "default", you can set the LANGCHAIN_SESSION environment variable to the name of the session you want to record to:
# import os
# os.environ["LANGCHAIN_HANDLER"] = "langchain"
# os.environ["LANGCHAIN_SESSION"] = "my_session" # Make sure this session actually exists. You can create a new session in the UI.
# To switch sessions mid-script or mid-notebook, do NOT set the LANGCHAIN_SESSION environment variable. Instead: langchain.set_tracing_callback_manager(session_name="my_session")
# previous
# Deployments
#  Contents
#
# Tracing Walkthrough
# Changing Sessions
# By Harrison Chase
#
#       © Copyright 2023, Harrison Chase.
#
#   Last updated on Apr 11, 2023.

# %% [markdown]
# We can also find the source of each document:

# %%
docs[0].metadata['source']
# Out:
# 'rtdocs/python.langchain.com/robots.txt.tmp'

# %%
docs[0].metadata['source'].replace('rtdocs/', 'https://')
# Out:
# 'https://python.langchain.com/robots.txt.tmp'

# %% [markdown]
# Now we store the documents as a data variable with two fields
# - text: the page_content of the html page
# - url: the link to the html page

# %%
data = [{'text': subdoc.page_content, 'url': subdoc.metadata['source'].replace('rtdocs/', 'https://')} for subdoc in docs]

# %%
len(data)
# Out:
# 475

# %% [markdown]
# Let's visualize one of the data index

# %%
data[1]
# Out:
# {'text': '.md\n.pdf\nTracing\n Contents \nTracing Walkthrough\nChanging Sessions\nTracing#\nBy enabling tracing in your LangChain runs, you’ll be able to more effectively visualize, step through, and debug your chains and agents.\nFirst, you should install tracing and set up your environment properly.\nYou can use either a locally hosted version of this (uses Docker) or a cloud hosted version (in closed alpha).\nIf you’re interested in using the hosted platform, please fill out the form here.\nLocally Hosted Setup\nCloud Hosted Setup\nTracing Walkthrough#\nWhen you first access the UI, you should see a page with your tracing sessions.\nAn initial one “default” should already be created for you.\nA session is just a way to group traces together.\nIf you click on a session, it will take you to a page with no recorded traces that says “No Runs.”\nYou can create a new session with the new session form.\nIf we click on the default session, we can see that to start we have no traces stored.\nIf we now start running chains and agents with tracing enabled, we will see data show up here.\nTo do so, we can run this notebook as an example.\nAfter running it, we will see an initial trace show up.\nFrom here we can explore the trace at a high level by clicking on the arrow to show nested runs.\nWe can keep on clicking further and further down to explore deeper and deeper.\nWe can also click on the “Explore” button of the top level run to dive even deeper.\nHere, we can see the inputs and outputs in full, as well as all the nested traces.\nWe can keep on exploring each of these nested traces in more detail.\nFor example, here is the lowest level trace with the exact inputs/outputs to the LLM.\nChanging Sessions#\nTo initially record traces to a session other than "default", you can set the LANGCHAIN_SESSION environment variable to the name of the session you want to record to:\nimport os\nos.environ["LANGCHAIN_HANDLER"] = "langchain"\nos.environ["LANGCHAIN_SESSION"] = "my_session" # Make sure this session actually exists. You can create a new session in the UI.\nTo switch sessions mid-script or mid-notebook, do NOT set the LANGCHAIN_SESSION environment variable. Instead: langchain.set_tracing_callback_manager(session_name="my_session")\nprevious\nDeployments\n Contents\n  \nTracing Walkthrough\nChanging Sessions\nBy Harrison Chase\n    \n      © Copyright 2023, Harrison Chase.\n      \n  Last updated on Apr 11, 2023.\n  ',
#  'url': 'https://python.langchain.com/en/latest/tracing.html'}

# %% [markdown]
# It's pretty ugly but it's good enough for now. Let's see how we can process all of these. We will chunk everything into ~400 token chunks, we can do this easily with `langchain` and `tiktoken`:

# %%
import tiktoken

tokenizer = tiktoken.get_encoding('p50k_base')

# create the length function
def tiktoken_len(text):
    tokens = tokenizer.encode(
        text,
        disallowed_special=()
    )
    return len(tokens)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=20,
    length_function=tiktoken_len,
    separators=["\n\n", "\n", " ", ""]
)

# %% [markdown]
# Process the `data` into more chunks using this approach.

# %%
from uuid import uuid4
from tqdm.auto import tqdm

chunks = []

for idx, record in enumerate(tqdm(data)):
    texts = text_splitter.split_text(record['text'])
    chunks.extend([{
        'id': str(uuid4()),
        'text': texts[i],
        'chunk': i,
        'url': record['url']
    } for i in range(len(texts))])
# Out:
#   0%|          | 0/475 [00:00<?, ?it/s]

# %%
len(chunks)
# Out:
# 2922

# %%
chunks[0]
# Out:
# {'id': '57b26110-8285-4c77-a798-2acba3d0c433',
#  'text': '.md\n.pdf\nTracing\n Contents \nTracing Walkthrough\nChanging Sessions\nTracing#\nBy enabling tracing in your LangChain runs, you’ll be able to more effectively visualize, step through, and debug your chains and agents.\nFirst, you should install tracing and set up your environment properly.\nYou can use either a locally hosted version of this (uses Docker) or a cloud hosted version (in closed alpha).\nIf you’re interested in using the hosted platform, please fill out the form here.\nLocally Hosted Setup\nCloud Hosted Setup\nTracing Walkthrough#\nWhen you first access the UI, you should see a page with your tracing sessions.\nAn initial one “default” should already be created for you.\nA session is just a way to group traces together.\nIf you click on a session, it will take you to a page with no recorded traces that says “No Runs.”\nYou can create a new session with the new session form.\nIf we click on the default session, we can see that to start we have no traces stored.\nIf we now start running chains and agents with tracing enabled, we will see data show up here.\nTo do so, we can run this notebook as an example.\nAfter running it, we will see an initial trace show up.\nFrom here we can explore the trace at a high level by clicking on the arrow to show nested runs.\nWe can keep on clicking further and further down to explore deeper and deeper.\nWe can also click on the “Explore” button of the top level run to dive even deeper.\nHere, we can see the inputs and outputs in full, as well as all the nested traces.\nWe can keep on exploring each of these nested traces in more detail.',
#  'chunk': 0,
#  'url': 'https://python.langchain.com/en/latest/tracing.html'}

# %%
chunks[1]
# Out:
# {'id': 'a11e55cf-5df2-4912-ba5a-a2ae6af35e87',
#  'text': 'We can keep on exploring each of these nested traces in more detail.\nFor example, here is the lowest level trace with the exact inputs/outputs to the LLM.\nChanging Sessions#\nTo initially record traces to a session other than "default", you can set the LANGCHAIN_SESSION environment variable to the name of the session you want to record to:\nimport os\nos.environ["LANGCHAIN_HANDLER"] = "langchain"\nos.environ["LANGCHAIN_SESSION"] = "my_session" # Make sure this session actually exists. You can create a new session in the UI.\nTo switch sessions mid-script or mid-notebook, do NOT set the LANGCHAIN_SESSION environment variable. Instead: langchain.set_tracing_callback_manager(session_name="my_session")\nprevious\nDeployments\n Contents\n  \nTracing Walkthrough\nChanging Sessions\nBy Harrison Chase\n    \n      © Copyright 2023, Harrison Chase.\n      \n  Last updated on Apr 11, 2023.',
#  'chunk': 1,
#  'url': 'https://python.langchain.com/en/latest/tracing.html'}

# %%
chunks[400]
# Out:
# {'id': '74cb597f-4e64-45f0-8350-43a8f8e9dd53',
#  'text': 'Source code for langchain.embeddings.self_hosted_hugging_face\n"""Wrapper around HuggingFace embedding models for self-hosted remote hardware."""\nimport importlib\nimport logging\nfrom typing import Any, Callable, List, Optional\nfrom langchain.embeddings.self_hosted import SelfHostedEmbeddings\nDEFAULT_MODEL_NAME = "sentence-transformers/all-mpnet-base-v2"\nDEFAULT_INSTRUCT_MODEL = "hkunlp/instructor-large"\nDEFAULT_EMBED_INSTRUCTION = "Represent the document for retrieval: "\nDEFAULT_QUERY_INSTRUCTION = (\n    "Represent the question for retrieving supporting documents: "\n)\nlogger = logging.getLogger(__name__)\ndef _embed_documents(client: Any, *args: Any, **kwargs: Any) -> List[List[float]]:\n    """Inference function to send to the remote hardware.\n    Accepts a sentence_transformer model_id and\n    returns a list of embeddings for each document in the batch.\n    """\n    return client.encode(*args, **kwargs)\ndef load_embedding_model(model_id: str, instruct: bool = False, device: int = 0) -> Any:\n    """Load the embedding model."""\n    if not instruct:\n        import sentence_transformers\n        client = sentence_transformers.SentenceTransformer(model_id)\n    else:\n        from InstructorEmbedding import INSTRUCTOR\n        client = INSTRUCTOR(model_id)\n    if importlib.util.find_spec("torch") is not None:\n        import torch',
#  'chunk': 0,
#  'url': 'https://python.langchain.com/en/latest/_modules/langchain/embeddings/self_hosted_hugging_face.html'}

# %%
chunks[401]
# Out:
# {'id': 'b7a6d30e-8996-48fe-9ef8-8792a1ca0a61',
#  'text': 'import torch\n        cuda_device_count = torch.cuda.device_count()\n        if device < -1 or (device >= cuda_device_count):\n            raise ValueError(\n                f"Got device=={device}, "\n                f"device is required to be within [-1, {cuda_device_count})"\n            )\n        if device < 0 and cuda_device_count > 0:\n            logger.warning(\n                "Device has %d GPUs available. "\n                "Provide device={deviceId} to `from_model_id` to use available"\n                "GPUs for execution. deviceId is -1 for CPU and "\n                "can be a positive integer associated with CUDA device id.",\n                cuda_device_count,\n            )\n        client = client.to(device)\n    return client\n[docs]class SelfHostedHuggingFaceEmbeddings(SelfHostedEmbeddings):\n    """Runs sentence_transformers embedding models on self-hosted remote hardware.\n    Supported hardware includes auto-launched instances on AWS, GCP, Azure,\n    and Lambda, as well as servers specified\n    by IP address and SSH credentials (such as on-prem, or another cloud\n    like Paperspace, Coreweave, etc.).\n    To use, you should have the ``runhouse`` python package installed.\n    Example:\n        .. code-block:: python\n            from langchain.embeddings import SelfHostedHuggingFaceEmbeddings\n            import runhouse as rh\n            model_name = "sentence-transformers/all-mpnet-base-v2"\n            gpu = rh.cluster(name="rh-a10x", instance_type="A100:1")',
#  'chunk': 1,
#  'url': 'https://python.langchain.com/en/latest/_modules/langchain/embeddings/self_hosted_hugging_face.html'}

# %% [markdown]
# Our chunks are ready so now we move onto embedding and indexing everything.

# %% [markdown]
# ## Initialize Embedding Model
#
# We use `text-embedding-ada-002` as the embedding model. We can embed text like so:

# %%
import openai

# initialize openai API key
openai.api_key = "<your-api-key>"  #platform.openai.com

embed_model = "text-embedding-ada-002"

res = openai.Embedding.create(
    input=[
        chunks[0]['text'], chunks[1]['text'], chunks[400]['text'], chunks[401]['text']
    ], engine=embed_model
)

# %% [markdown]
# In the response `res` we will find a JSON-like object containing our new embeddings within the `'data'` field.

# %%
res.keys()
# Out:
# dict_keys(['object', 'data', 'model', 'usage'])

# %% [markdown]
# Inside `'data'` we will find two records, one for each of the two sentences we just embedded. Each vector embedding contains `1536` dimensions (the output dimensionality of the `text-embedding-ada-002` model.

# %%
len(res['data'])
# Out:
# 4

# %%
len(res['data'][0]['embedding']), len(res['data'][1]['embedding'])
# Out:
# (1536, 1536)

# %% [markdown]
# We will apply this same embedding logic to the langchain docs dataset we've just scraped. But before doing so we must create a place to store the embeddings.

# %% [markdown]
# Visualize the cosine similarity between embeddings (same as dot product)

# %%
import itertools

combinations = list(itertools.combinations(range(4), 2))
for first,second in combinations:
  print(f'Similarity between {first} and {second}', np.dot(res['data'][first]['embedding'], res['data'][second]['embedding']))
# Out:
# Similarity between 0 and 1 0.8790477489737241
# Similarity between 0 and 2 0.6479160827111908
# Similarity between 0 and 3 0.6710545200749323
# Similarity between 1 and 2 0.6552577593400561
# Similarity between 1 and 3 0.6590764328448566
# Similarity between 2 and 3 0.8292819084110552

# %% [markdown]
# Check the magnitude of each vector

# %%
[np.linalg.norm(res['data'][i]['embedding']) for i in range(4)]
# Out:
# [1.0000000210234485,
#  1.0000000155647548,
#  0.9999999802991162,
#  1.0000000373702902]

# %% [markdown]
# ## Initializing the Index

# %% [markdown]
# Now we need a place to store these embeddings and enable a efficient vector search through them all. To do that we use Pinecone, we can get a [free API key](https://app.pinecone.io/) and enter it below where we will initialize our connection to Pinecone and create a new index.

# %%
import pinecone

index_name = 'gpt-4-langchain-docs'

# initialize connection to pinecone
pinecone.init(
    api_key="<your-api-key>",  # app.pinecone.io (console)
    environment="<your-environment>"  # next to API key in console
)

# check if index already exists (it shouldn't if this is first time)
if index_name not in pinecone.list_indexes():
    # if does not exist, create index
    pinecone.create_index(
        index_name,
        dimension=len(res['data'][0]['embedding']),
        metric='dotproduct'
    )
# connect to index
index = pinecone.GRPCIndex(index_name)
# view index stats
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %% [markdown]
# We can see the index is currently empty with a `total_vector_count` of `0`. We can begin populating it with OpenAI `text-embedding-ada-002` built embeddings like so:

# %%
from tqdm.auto import tqdm
import datetime
from time import sleep

batch_size = 100  # how many embeddings we create and insert at once

for i in tqdm(range(0, len(chunks), batch_size)):
    # find end of batch
    i_end = min(len(chunks), i+batch_size)
    meta_batch = chunks[i:i_end]
    # get ids
    ids_batch = [x['id'] for x in meta_batch]
    # get texts to encode
    texts = [x['text'] for x in meta_batch]
    # create embeddings (try-except added to avoid RateLimitError)
    try:
        res = openai.Embedding.create(input=texts, engine=embed_model)
    except:
        done = False
        while not done:
            sleep(5)
            try:
                res = openai.Embedding.create(input=texts, engine=embed_model)
                done = True
            except:
                pass
    embeds = [record['embedding'] for record in res['data']]
    # cleanup metadata
    meta_batch = [{
        'text': x['text'],
        'chunk': x['chunk'],
        'url': x['url']
    } for x in meta_batch]
    to_upsert = list(zip(ids_batch, embeds, meta_batch))
    # upsert to Pinecone
    index.upsert(vectors=to_upsert)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# Now we've added all of our langchain docs to the index. With that we can move on to retrieval and then answer generation using ChatGPT.

# %% [markdown]
# ## Retrieval

# %% [markdown]
# To search through our documents we first need to create a query vector `xq`. Using `xq` we will retrieve the most relevant chunks from the LangChain docs, like so:

# %%
query = "how do I use the React Agent in LangChain?"

# Get embedding from OpenAI
res = openai.Embedding.create(
    input=[query],
    engine=embed_model
)

xq = res['data'][0]['embedding']

# get relevant contexts (including the questions)
res = index.query(xq, top_k=5, include_metadata=True)

# %%
res
# Out:
# {'matches': [{'id': 'af0ae51f-1ac9-48d1-bacc-45b704c9f0d1',
#               'metadata': {'chunk': 0.0,
#                            'text': '.md\n'
#                                    '.pdf\n'
#                                    'Agent Types\n'
#                                    ' Contents \n'
#                                    'zero-shot-react-description\n'
#                                    'react-docstore\n'
#                                    'self-ask-with-search\n'
#                                    'conversational-react-description\n'
#                                    'Agent Types#\n'
#                                    'Agents use an LLM to determine which '
#                                    'actions to take and in what order.\n'
#                                    'An action can either be using a tool and '
#                                    'observing its output, or returning a '
#                                    'response to the user.\n'
#                                    'Here are the agents available in '
#                                    'LangChain.\n'
#                                    'zero-shot-react-description#\n'
#                                    'This agent uses the ReAct framework to '
#                                    'determine which tool to use\n'
#                                    'based solely on the tool’s description. '
#                                    'Any number of tools can be provided.\n'
#                                    'This agent requires that a description is '
#                                    'provided for each tool.\n'
#                                    'react-docstore#\n'
#                                    'This agent uses the ReAct framework to '
#                                    'interact with a docstore. Two tools must\n'
#                                    'be provided: a Search tool and a Lookup '
#                                    'tool (they must be named exactly as so).\n'
#                                    'The Search tool should search for a '
#                                    'document, while the Lookup tool should '
#                                    'lookup\n'
#                                    'a term in the most recently found '
#                                    'document.\n'
#                                    'This agent is equivalent to the\n'
#                                    'original ReAct paper, specifically the '
#                                    'Wikipedia example.\n'
#                                    'self-ask-with-search#\n'
#                                    'This agent utilizes a single tool that '
#                                    'should be named Intermediate Answer.\n'
#                                    'This tool should be able to lookup factual '
#                                    'answers to questions. This agent\n'
#                                    'is equivalent to the original self ask '
#                                    'with search paper,\n'
#                                    'where a Google search API was provided as '
#                                    'the tool.\n'
#                                    'conversational-react-description#\n'
#                                    'This agent is designed to be used in '
#                                    'conversational settings.\n'
#                                    'The prompt is designed to make the agent '
#                                    'helpful and conversational.\n'
#                                    'It uses the ReAct framework to decide '
#                                    'which tool to use, and uses memory to '
#                                    'remember the previous conversation '
#                                    'interactions.\n'
#                                    'previous\n'
#                                    'Agents\n'
#                                    'next\n'
#                                    'Custom Agent\n'
#                                    ' Contents\n'
#                                    '  \n'
#                                    'zero-shot-react-description\n'
#                                    'react-docstore\n'
#                                    'self-ask-with-search',
#                            'url': 'https://python.langchain.com/en/latest/modules/agents/agents/agent_types.html'},
#               'score': 0.84282166,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []},
#              {'id': 'e84a2f28-4205-47b7-9690-bc3db132133d',
#               'metadata': {'chunk': 1.0,
#                            'text': 'Chains: Chains go beyond just a single LLM '
#                                    'call, and are sequences of calls (whether '
#                                    'to an LLM or a different utility). '
#                                    'LangChain provides a standard interface '
#                                    'for chains, lots of integrations with '
#                                    'other tools, and end-to-end chains for '
#                                    'common applications.\n'
#                                    'Agents: Agents involve an LLM making '
#                                    'decisions about which Actions to take, '
#                                    'taking that Action, seeing an Observation, '
#                                    'and repeating that until done. LangChain '
#                                    'provides a standard interface for agents, '
#                                    'a selection of agents to choose from, and '
#                                    'examples of end to end agents.\n'
#                                    'Use Cases#\n'
#                                    'The above modules can be used in a variety '
#                                    'of ways. LangChain also provides guidance '
#                                    'and assistance in this. Below are some of '
#                                    'the common use cases LangChain supports.\n'
#                                    'Personal Assistants: The main LangChain '
#                                    'use case. Personal assistants need to take '
#                                    'actions, remember interactions, and have '
#                                    'knowledge about your data.\n'
#                                    'Question Answering: The second big '
#                                    'LangChain use case. Answering questions '
#                                    'over specific documents, only utilizing '
#                                    'the information in those documents to '
#                                    'construct an answer.\n'
#                                    'Chatbots: Since language models are good '
#                                    'at producing text, that makes them ideal '
#                                    'for creating chatbots.\n'
#                                    'Querying Tabular Data: If you want to '
#                                    'understand how to use LLMs to query data '
#                                    'that is stored in a tabular format (csvs, '
#                                    'SQL, dataframes, etc) you should read this '
#                                    'page.\n'
#                                    'Code Understanding: If you want to '
#                                    'understand how to use LLMs to query source '
#                                    'code from github, you should read this '
#                                    'page.\n'
#                                    'Interacting with APIs: Enabling LLMs to '
#                                    'interact with APIs is extremely powerful '
#                                    'in order to give them more up-to-date '
#                                    'information and allow them to take '
#                                    'actions.\n'
#                                    'Extraction: Extract structured information '
#                                    'from text.\n'
#                                    'Summarization: Summarizing longer '
#                                    'documents into shorter, more condensed '
#                                    'chunks of information. A type of Data '
#                                    'Augmented Generation.',
#                            'url': 'https://python.langchain.com/en/latest/index.html'},
#               'score': 0.83088297,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []},
#              {'id': 'a263217c-469a-4866-b0b5-58ccd28c487d',
#               'metadata': {'chunk': 1.0,
#                            'text': 'Chains: Chains go beyond just a single LLM '
#                                    'call, and are sequences of calls (whether '
#                                    'to an LLM or a different utility). '
#                                    'LangChain provides a standard interface '
#                                    'for chains, lots of integrations with '
#                                    'other tools, and end-to-end chains for '
#                                    'common applications.\n'
#                                    'Agents: Agents involve an LLM making '
#                                    'decisions about which Actions to take, '
#                                    'taking that Action, seeing an Observation, '
#                                    'and repeating that until done. LangChain '
#                                    'provides a standard interface for agents, '
#                                    'a selection of agents to choose from, and '
#                                    'examples of end to end agents.\n'
#                                    'Use Cases#\n'
#                                    'The above modules can be used in a variety '
#                                    'of ways. LangChain also provides guidance '
#                                    'and assistance in this. Below are some of '
#                                    'the common use cases LangChain supports.\n'
#                                    'Personal Assistants: The main LangChain '
#                                    'use case. Personal assistants need to take '
#                                    'actions, remember interactions, and have '
#                                    'knowledge about your data.\n'
#                                    'Question Answering: The second big '
#                                    'LangChain use case. Answering questions '
#                                    'over specific documents, only utilizing '
#                                    'the information in those documents to '
#                                    'construct an answer.\n'
#                                    'Chatbots: Since language models are good '
#                                    'at producing text, that makes them ideal '
#                                    'for creating chatbots.\n'
#                                    'Querying Tabular Data: If you want to '
#                                    'understand how to use LLMs to query data '
#                                    'that is stored in a tabular format (csvs, '
#                                    'SQL, dataframes, etc) you should read this '
#                                    'page.\n'
#                                    'Code Understanding: If you want to '
#                                    'understand how to use LLMs to query source '
#                                    'code from github, you should read this '
#                                    'page.\n'
#                                    'Interacting with APIs: Enabling LLMs to '
#                                    'interact with APIs is extremely powerful '
#                                    'in order to give them more up-to-date '
#                                    'information and allow them to take '
#                                    'actions.\n'
#                                    'Extraction: Extract structured information '
#                                    'from text.\n'
#                                    'Summarization: Summarizing longer '
#                                    'documents into shorter, more condensed '
#                                    'chunks of information. A type of Data '
#                                    'Augmented Generation.',
#                            'url': 'https://langchain.readthedocs.io/en/latest/index.html'},
#               'score': 0.83088297,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []},
#              {'id': 'a4abc2c4-3061-4b77-a5db-0726b4e458cc',
#               'metadata': {'chunk': 26.0,
#                            'text': 'the concept of persisting state between '
#                                    'calls of a chain/agent. LangChain provides '
#                                    'a standard interface for memory, a '
#                                    'collection of memory implementations, and '
#                                    'examples of chains/agents that use '
#                                    'memory.\\nIndexes: Language models are '
#                                    'often more powerful when combined with '
#                                    'your own text data - this module covers '
#                                    'best practices for doing exactly '
#                                    'that.\\nChains: Chains go beyond just a '
#                                    'single LLM call, and are sequences of '
#                                    'calls (whether to an LLM or a different '
#                                    'utility). LangChain provides a standard '
#                                    'interface for chains, lots of integrations '
#                                    'with other tools, and end-to-end chains '
#                                    'for common applications.\\nAgents: Agents '
#                                    'involve an LLM making decisions about '
#                                    'which Actions to take, taking that Action, '
#                                    'seeing an Observation, and repeating that '
#                                    'until done. LangChain provides a standard '
#                                    'interface for agents, a selection of '
#                                    'agents to choose from, and examples of end '
#                                    'to end agents.\\n\\n\\n\\n\\n\\nUse '
#                                    'Cases#\\nThe above modules can be used in '
#                                    'a variety of ways. LangChain also provides',
#                            'url': 'https://python.langchain.com/en/latest/modules/indexes/document_loaders/examples/sitemap.html'},
#               'score': 0.8261658,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []},
#              {'id': '713cb886-1844-44bf-9568-56efab0d06e8',
#               'metadata': {'chunk': 10.0,
#                            'text': 'standard interface for chains, lots of '
#                                    'integrations with other tools, and '
#                                    'end-to-end chains for common '
#                                    'applications.\\nIndexes: Language models '
#                                    'are often more powerful when combined with '
#                                    'your own text data - this module covers '
#                                    'best practices for doing exactly '
#                                    'that.\\nAgents: Agents involve an LLM '
#                                    'making decisions about which Actions to '
#                                    'take, taking that Action, seeing an '
#                                    'Observation, and repeating that until '
#                                    'done. LangChain provides a standard '
#                                    'interface for agents, a selection of '
#                                    'agents to choose from, and examples of end '
#                                    'to end agents.\\nMemory: Memory is the '
#                                    'concept of persisting state between calls '
#                                    'of a chain/agent. LangChain provides a '
#                                    'standard interface for memory, a '
#                                    'collection of memory implementations, and '
#                                    'examples of chains/agents that use '
#                                    'memory.\\nChat: Chat models are a '
#                                    'variation on Language Models that expose a '
#                                    'different API - rather than working with '
#                                    'raw text, they work with messages. '
#                                    'LangChain provides a standard interface '
#                                    'for working with them and doing all the '
#                                    'same things as above.\\n\\n\\n\\n\\n\\nUse',
#                            'url': 'https://python.langchain.com/en/latest/modules/indexes/document_loaders/examples/sitemap.html'},
#               'score': 0.8244102,
#               'sparse_values': {'indices': [], 'values': []},
#               'values': []}],
#  'namespace': ''}

# %% [markdown]
# With retrieval complete, we move on to feeding these into GPT-4 to produce answers.

# %% [markdown]
# ## Retrieval Augmented Generation

# %% [markdown]
# GPT-4 is currently accessed via the `ChatCompletions` endpoint of OpenAI. To add the information we retrieved into the model, we need to pass it into our user prompts *alongside* our original query. We can do that like so:

# %%
# get list of retrieved text
contexts = [item['metadata']['text'] for item in res['matches']]

augmented_query = "\n\n---\n\n".join(contexts)+"\n\n-----\n\n"+query

# %%
print(augmented_query)
# Out:
# for all LLMs, and common utilities for working with LLMs.\n\nð\x9f”\x97 Chains:\n\nChains go beyond just a single LLM call, and are sequences of calls (whether to an LLM or a different utility). LangChain provides a standard interface for chains, lots of integrations with other tools, and end-to-end chains for common applications.\n\nð\x9f“\x9a Data Augmented Generation:\n\nData Augmented Generation involves specific types of chains that first interact with an external datasource to fetch data to use in the generation step. Examples of this include summarization of long pieces of text and question/answering over specific data sources.\n\nð\x9f¤\x96 Agents:\n\nAgents involve an LLM making decisions about which Actions to take, taking that Action, seeing an Observation, and repeating that until done. LangChain provides a standard interface for agents, a selection of agents to choose from, and examples of end to end
#
# ---
#
# Chains: Chains go beyond just a single LLM call, and are sequences of calls (whether to an LLM or a different utility). LangChain provides a standard interface for chains, lots of integrations with other tools, and end-to-end chains for common applications.
# Agents: Agents involve an LLM making decisions about which Actions to take, taking that Action, seeing an Observation, and repeating that until done. LangChain provides a standard interface for agents, a selection of agents to choose from, and examples of end to end agents.
# Use Cases#
# The above modules can be used in a variety of ways. LangChain also provides guidance and assistance in this. Below are some of the common use cases LangChain supports.
# Personal Assistants: The main LangChain use case. Personal assistants need to take actions, remember interactions, and have knowledge about your data.
# Question Answering: The second big LangChain use case. Answering questions over specific documents, only utilizing the information in those documents to construct an answer.
# Chatbots: Since language models are good at producing text, that makes them ideal for creating chatbots.
# Querying Tabular Data: If you want to understand how to use LLMs to query data that is stored in a tabular format (csvs, SQL, dataframes, etc) you should read this page.
# Code Understanding: If you want to understand how to use LLMs to query source code from github, you should read this page.
# Interacting with APIs: Enabling LLMs to interact with APIs is extremely powerful in order to give them more up-to-date information and allow them to take actions.
# Extraction: Extract structured information from text.
# Summarization: Summarizing longer documents into shorter, more condensed chunks of information. A type of Data Augmented Generation.
#
# ---
#
# Chains: Chains go beyond just a single LLM call, and are sequences of calls (whether to an LLM or a different utility). LangChain provides a standard interface for chains, lots of integrations with other tools, and end-to-end chains for common applications.
# Agents: Agents involve an LLM making decisions about which Actions to take, taking that Action, seeing an Observation, and repeating that until done. LangChain provides a standard interface for agents, a selection of agents to choose from, and examples of end to end agents.
# Use Cases#
# The above modules can be used in a variety of ways. LangChain also provides guidance and assistance in this. Below are some of the common use cases LangChain supports.
# Personal Assistants: The main LangChain use case. Personal assistants need to take actions, remember interactions, and have knowledge about your data.
# Question Answering: The second big LangChain use case. Answering questions over specific documents, only utilizing the information in those documents to construct an answer.
# Chatbots: Since language models are good at producing text, that makes them ideal for creating chatbots.
# Querying Tabular Data: If you want to understand how to use LLMs to query data that is stored in a tabular format (csvs, SQL, dataframes, etc) you should read this page.
# Code Understanding: If you want to understand how to use LLMs to query source code from github, you should read this page.
# Interacting with APIs: Enabling LLMs to interact with APIs is extremely powerful in order to give them more up-to-date information and allow them to take actions.
# Extraction: Extract structured information from text.
# Summarization: Summarizing longer documents into shorter, more condensed chunks of information. A type of Data Augmented Generation.
#
# ---
#
# in a variety of ways. LangChain also provides guidance and assistance in this. Below are some of the common use cases LangChain supports.\n\nPersonal Assistants: The main LangChain use case. Personal assistants need to take actions, remember interactions, and have knowledge about your data.\nQuestion Answering: The second big LangChain use case. Answering questions over specific documents, only utilizing the information in those documents to construct an answer.\nChatbots: Since language models are good at producing text, that makes them ideal for creating chatbots.\nQuerying Tabular Data: If you want to understand how to use LLMs to query data that is stored in a tabular format (csvs, SQL, dataframes, etc) you should read this page.\nInteracting with APIs: Enabling LLMs to interact with APIs is extremely powerful in order to give them more up-to-date information and allow them to take actions.\nExtraction: Extract structured information from text.\nSummarization: Summarizing longer documents into
#
# ---
#
# are several main modules that LangChain provides support for.\nFor each module we provide some examples to get started, how-to guides, reference docs, and conceptual guides.\nThese modules are, in increasing order of complexity:\n\nPrompts: This includes prompt management, prompt optimization, and prompt serialization.\nLLMs: This includes a generic interface for all LLMs, and common utilities for working with LLMs.\nDocument Loaders: This includes a standard interface for loading documents, as well as specific integrations to all types of text data sources.\nUtils: Language models are often more powerful when interacting with other sources of knowledge or computation. This can include Python REPLs, embeddings, search engines, and more. LangChain provides a large collection of common utils to use in your application.\nChains: Chains go beyond just a single LLM call, and are sequences of calls (whether to an LLM or a different utility). LangChain provides a standard interface for chains, lots of integrations with other
#
# -----
#
# how do I use the LLMChain in LangChain?

# %% [markdown]
# Now we ask the question:

# %%
# system message to 'prime' the model
primer = f"""You are Q&A bot. A highly intelligent system that answers
user questions based on the information provided by the user above
each question. If the information can not be found in the information
provided by the user you truthfully say "I don't know".
"""

res = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": primer},
        {"role": "user", "content": augmented_query}
    ]
)

# %% [markdown]
# To display this response nicely, we will display it in markdown.

# %%
from IPython.display import Markdown

display(Markdown(res['choices'][0]['message']['content']))
# Out:
# LangChain provides a standard interface for chains, called LangChain. You can use it to sequence calls to an LLM or a different utility to create chains. There are lots of integrations with other tools and end-to-end chains for common applications. You can find examples and guidance on how to use LLMChain in LangChain on their website.

# %% [markdown]
# #Non-augmented query
# Let's compare this to a non-augmented query...

# %%
res = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": primer},
        {"role": "user", "content": query}
    ]
)
display(Markdown(res['choices'][0]['message']['content']))
# Out:
# I apologize, but I don't have enough information to answer your question. Could you please provide more context or details about what LLMChain and LangChain are and how they are related?

# %% [markdown]
# If we drop the `"I don't know"` part of the `primer`?

# %%
res = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are Q&A bot. A highly intelligent system that answers user questions"},
        {"role": "user", "content": query}
    ]
)
display(Markdown(res['choices'][0]['message']['content']))
# Out:
# The LLMChain is a blockchain-based system that forms a part of the LangChain ecosystem. To use LLMChain, you will first need to create an account on the LangChain platform. Once you have created an account, you can then start using the LLMChain platform to access and transact in Langcoin cryptocurrency.
#
# To get started, you will need to download and install a digital wallet that supports LangCoin. You can then use this wallet to store and manage your LangCoin holdings. To acquire Langcoin, you can purchase them from a supported exchange or obtain them through mining.
#
# Once you have LangCoins in your wallet, you can use them to make transactions on the LLMChain platform. This can include buying products and services from businesses that accept Langcoin as a payment method.
#
# The LLMChain also has smart contract capabilities that allow users to create and execute self-executing contracts without the need for intermediaries. These contracts can govern various types of transactions, including the transfer of assets, property rights, and financial instruments.
#
# In conclusion, to use LLMChain in LangChain, you need to create an account on the LangChain platform, obtain LangCoins and a digital wallet that supports LangCoin, and use the LLMChain platform to initiate transactions and execute smart contracts.

# %% [markdown]
# # Let's try to make GPT output the url as well

# %%
query = "how do I use the React Agent in LangChain?"

# Get embedding from OpenAI
res = openai.Embedding.create(
    input=[query],
    engine=embed_model
)

xq = res['data'][0]['embedding']

# get relevant contexts (including the questions)
res = index.query(xq, top_k=5, include_metadata=True)

# %%
# get list of retrieved text
contexts = ['Text: '+item['metadata']['text']+'\nUrl: '+item['metadata']['url'] for item in res['matches']]

augmented_query = "\n\n---\n\n".join(contexts)+"\n\n-----\n\n"+query

# %%
print(augmented_query)
# Out:
# Text: .md
# .pdf
# Agent Types
#  Contents
# zero-shot-react-description
# react-docstore
# self-ask-with-search
# conversational-react-description
# Agent Types#
# Agents use an LLM to determine which actions to take and in what order.
# An action can either be using a tool and observing its output, or returning a response to the user.
# Here are the agents available in LangChain.
# zero-shot-react-description#
# This agent uses the ReAct framework to determine which tool to use
# based solely on the tool’s description. Any number of tools can be provided.
# This agent requires that a description is provided for each tool.
# react-docstore#
# This agent uses the ReAct framework to interact with a docstore. Two tools must
# be provided: a Search tool and a Lookup tool (they must be named exactly as so).
# The Search tool should search for a document, while the Lookup tool should lookup
# a term in the most recently found document.
# This agent is equivalent to the
# original ReAct paper, specifically the Wikipedia example.
# self-ask-with-search#
# This agent utilizes a single tool that should be named Intermediate Answer.
# This tool should be able to lookup factual answers to questions. This agent
# is equivalent to the original self ask with search paper,
# where a Google search API was provided as the tool.
# conversational-react-description#
# This agent is designed to be used in conversational settings.
# The prompt is designed to make the agent helpful and conversational.
# It uses the ReAct framework to decide which tool to use, and uses memory to remember the previous conversation interactions.
# previous
# Agents
# next
# Custom Agent
#  Contents
#
# zero-shot-react-description
# react-docstore
# self-ask-with-search
# Url: https://python.langchain.com/en/latest/modules/agents/agents/agent_types.html
#
# ---
#
# Text: Chains: Chains go beyond just a single LLM call, and are sequences of calls (whether to an LLM or a different utility). LangChain provides a standard interface for chains, lots of integrations with other tools, and end-to-end chains for common applications.
# Agents: Agents involve an LLM making decisions about which Actions to take, taking that Action, seeing an Observation, and repeating that until done. LangChain provides a standard interface for agents, a selection of agents to choose from, and examples of end to end agents.
# Use Cases#
# The above modules can be used in a variety of ways. LangChain also provides guidance and assistance in this. Below are some of the common use cases LangChain supports.
# Personal Assistants: The main LangChain use case. Personal assistants need to take actions, remember interactions, and have knowledge about your data.
# Question Answering: The second big LangChain use case. Answering questions over specific documents, only utilizing the information in those documents to construct an answer.
# Chatbots: Since language models are good at producing text, that makes them ideal for creating chatbots.
# Querying Tabular Data: If you want to understand how to use LLMs to query data that is stored in a tabular format (csvs, SQL, dataframes, etc) you should read this page.
# Code Understanding: If you want to understand how to use LLMs to query source code from github, you should read this page.
# Interacting with APIs: Enabling LLMs to interact with APIs is extremely powerful in order to give them more up-to-date information and allow them to take actions.
# Extraction: Extract structured information from text.
# Summarization: Summarizing longer documents into shorter, more condensed chunks of information. A type of Data Augmented Generation.
# Url: https://python.langchain.com/en/latest/index.html
#
# ---
#
# Text: Chains: Chains go beyond just a single LLM call, and are sequences of calls (whether to an LLM or a different utility). LangChain provides a standard interface for chains, lots of integrations with other tools, and end-to-end chains for common applications.
# Agents: Agents involve an LLM making decisions about which Actions to take, taking that Action, seeing an Observation, and repeating that until done. LangChain provides a standard interface for agents, a selection of agents to choose from, and examples of end to end agents.
# Use Cases#
# The above modules can be used in a variety of ways. LangChain also provides guidance and assistance in this. Below are some of the common use cases LangChain supports.
# Personal Assistants: The main LangChain use case. Personal assistants need to take actions, remember interactions, and have knowledge about your data.
# Question Answering: The second big LangChain use case. Answering questions over specific documents, only utilizing the information in those documents to construct an answer.
# Chatbots: Since language models are good at producing text, that makes them ideal for creating chatbots.
# Querying Tabular Data: If you want to understand how to use LLMs to query data that is stored in a tabular format (csvs, SQL, dataframes, etc) you should read this page.
# Code Understanding: If you want to understand how to use LLMs to query source code from github, you should read this page.
# Interacting with APIs: Enabling LLMs to interact with APIs is extremely powerful in order to give them more up-to-date information and allow them to take actions.
# Extraction: Extract structured information from text.
# Summarization: Summarizing longer documents into shorter, more condensed chunks of information. A type of Data Augmented Generation.
# Url: https://langchain.readthedocs.io/en/latest/index.html
#
# ---
#
# Text: the concept of persisting state between calls of a chain/agent. LangChain provides a standard interface for memory, a collection of memory implementations, and examples of chains/agents that use memory.\nIndexes: Language models are often more powerful when combined with your own text data - this module covers best practices for doing exactly that.\nChains: Chains go beyond just a single LLM call, and are sequences of calls (whether to an LLM or a different utility). LangChain provides a standard interface for chains, lots of integrations with other tools, and end-to-end chains for common applications.\nAgents: Agents involve an LLM making decisions about which Actions to take, taking that Action, seeing an Observation, and repeating that until done. LangChain provides a standard interface for agents, a selection of agents to choose from, and examples of end to end agents.\n\n\n\n\n\nUse Cases#\nThe above modules can be used in a variety of ways. LangChain also provides
# Url: https://python.langchain.com/en/latest/modules/indexes/document_loaders/examples/sitemap.html
#
# ---
#
# Text: standard interface for chains, lots of integrations with other tools, and end-to-end chains for common applications.\nIndexes: Language models are often more powerful when combined with your own text data - this module covers best practices for doing exactly that.\nAgents: Agents involve an LLM making decisions about which Actions to take, taking that Action, seeing an Observation, and repeating that until done. LangChain provides a standard interface for agents, a selection of agents to choose from, and examples of end to end agents.\nMemory: Memory is the concept of persisting state between calls of a chain/agent. LangChain provides a standard interface for memory, a collection of memory implementations, and examples of chains/agents that use memory.\nChat: Chat models are a variation on Language Models that expose a different API - rather than working with raw text, they work with messages. LangChain provides a standard interface for working with them and doing all the same things as above.\n\n\n\n\n\nUse
# Url: https://python.langchain.com/en/latest/modules/indexes/document_loaders/examples/sitemap.html
#
# -----
#
# how do I use the React Agent in LangChain?

# %%
# system message to 'prime' the model
primer = f"""You are Q&A bot. A highly intelligent system that answers
user questions based on the information provided by the user above
each question. If the information can not be found in the information
provided by the user you truthfully say "I don't know. 

You will receive some background information of the format 'Text: <text> Url: <url>'.
You are to answer the user by citing each part of the answer you provide with the relevant url in brackets at the end of the part.
The format for answersing for each url is as such: '<Answer from url1>(<url1>) <Answer from url2>(<url2>)'
Use at least 2 urls if possible".
"""

res = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": primer},
        {"role": "user", "content": augmented_query}
    ]
)

# %%
display(Markdown(res['choices'][0]['message']['content']))
# Out:
# The React Agent in LangChain is used to determine which tool to use based solely on the tool’s description (zero-shot-react-description). The agent requires that a description is provided for each tool. You can refer to the LangChain documentation for more information on how to use the React Agent (https://python.langchain.com/en/latest/modules/agents/agents/agent_types.html).
